# %% [markdown]
# # 1. In a jupyter notebook, using the appropriate markdown method include at least one link to a website, news article or blog which discusses ethical issues with computer vision applications and add your personal thoughts and interpretation of this issue.

# %% [markdown]
# [click here](https://fortune.com/2021/11/12/bias-ai-ethical-issue-racism-data-technology/)

# %% [markdown]
# # 2. use the https://vision-explorer.allenai.org/text_to_image_generation to generate an image from a caption you provide (choosing a theme from the drop down list), which you should display inside your notebook with the caption you provided and an evaluation of how good a job you feel the machine has done-hint: you will need an image display method, for example

# %% [markdown]
# Caption: Two people playing videogames

# %%
from IPython.display import Image
Image('download.png')

# %% [markdown]
# This image is supposed to be two people playing video games but instead the model blurted out some nightmare fuel. So, no the machine has not done a very good job at generating a photo of the caption.

# %% [markdown]
# # 3. read this blog article. Link the url to your notebook using the appropriate markdown technique and add a summary into your notebook (as markdown) of any image processing steps you saw the author employ.

# %% [markdown]
# [click here](https://thedatafrog.com/en/articles/dogs-vs-cats/)

# %% [markdown]
# The author dived deep into his data and mentioned that data is always dirty in the sense that he found a lot of cartoon photos of cats and dogs that might not be of any relevancy to the project.
